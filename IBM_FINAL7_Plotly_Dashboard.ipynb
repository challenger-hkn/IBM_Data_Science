# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
# from jupyter_dash import JupyterDash
import plotly.graph_objects as go
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.io as pio
# pio.renderers.default = "vscode"
# !pip install jupyter_dash
from jupyter_dash import JupyterDash
# Out:
# Requirement already satisfied: jupyter_dash in c:\users\hakan\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: retrying in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: dash in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (2.10.2)
# Requirement already satisfied: ipykernel in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (6.15.2)
# Requirement already satisfied: requests in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (2.27.1)
# Requirement already satisfied: nest-asyncio in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (1.5.6)
# Requirement already satisfied: ipython in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (8.8.0)
# Requirement already satisfied: flask in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ansi2html in c:\users\hakan\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hakan\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hakan\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.14.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hakan\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hakan\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\hakan\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\hakan\anaconda3\lib\site-packages (from flask->jupyter_dash) (3.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\hakan\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\hakan\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: colorama in c:\users\hakan\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hakan\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hakan\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\hakan\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (21.3)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: psutil in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (7.1.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hakan\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: decorator in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.26)
# Requirement already satisfied: backcall in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\hakan\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hakan\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hakan\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (4.9.1)
# Requirement already satisfied: entrypoints in c:\users\hakan\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hakan\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hakan\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (302)
# Requirement already satisfied: wcwidth in c:\users\hakan\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\hakan\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hakan\anaconda3\lib\site-packages (from packaging->plotly>=5.0.0->dash->jupyter_dash) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hakan\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hakan\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hakan\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hakan\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: asttokens in c:\users\hakan\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hakan\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: executing in c:\users\hakan\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 50}),
                                # Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                            options=[
                                                {'label': 'All Sites', 'value': 'ALL'},
                                                {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                            ],
                                            value='ALL',
                                            placeholder="place holder here",
                                            searchable=True
                                            ),
                                html.Br(),

                                # Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0',
                                                       2500: '2500',
                                                       5000: '5000',
                                                       7500: '7500',
                                                       10000: '10000'},
                                                value=[min_payload, max_payload]),
                                # Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    if entered_site == 'ALL':
        fig = px.pie(spacex_df, values='class', 
        names='Launch Site', color_discrete_sequence=px.colors.sequential.RdBu,
        title='Total Success Launches By Sites')
        fig.update_traces(textposition='inside', textinfo='percent+label')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df.loc[(spacex_df['Launch Site']==entered_site), ['Launch Site', 'class']].groupby(by='class', as_index=False).count()
        fig = px.pie(filtered_df, values='Launch Site', 
        names='class', 
        title='Total Success Launches for Site ' + str(entered_site))
        fig.update_traces(textposition='inside', textinfo='percent+label') # text inside
        return fig

# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'), 
               Input(component_id="payload-slider", component_property="value")])
def get_scatter_chart(entered_site, payload):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= payload[0]) & 
                            (spacex_df['Payload Mass (kg)']<= payload[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', color='Booster Version Category',
        title='Correlation between Payload and Success for all Sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        fig = px.scatter(filtered_df[filtered_df['Launch Site']==entered_site], 
                         x='Payload Mass (kg)', y='class', color='Booster Version Category',
                        title='Correlation between Payload and Success for Site ' + str(entered_site)) 
        return fig
# Run the app
if __name__ == '__main__':
    app.run_server(mode='jupyterlab', port = 8090 ,dev_tools_ui=True, #debug=True,
              dev_tools_hot_reload =True, threaded=True)
# Out:
# Dash is running on http://127.0.0.1:8090/
